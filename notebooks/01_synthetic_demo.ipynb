# %% [markdown]
# # ProFair Observability synthetic demonstration
# This notebook uses synthetic pseudonymous data only.

# %%
import pandas as pd

from profair_observability.config import AlgorithmConfig
from profair_observability.metrics import compute_profile

data = pd.read_csv('../examples/synthetic_exhibitors.csv')
benchmarks = pd.read_csv('../examples/synthetic_benchmarks.csv')
config = AlgorithmConfig.from_yaml('../examples/config.yml')
compute_profile(data, benchmarks=benchmarks, config=config)
